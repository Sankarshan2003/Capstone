# %%
from ultralytics import YOLO
import torch

# %%
model = YOLO(r'C:\Users\sanka\OneDrive\Desktop\capstone\oldGantryRobot\train2\weights\best.pt')
res = model.predict(source=r'C:\Users\sanka\OneDrive\Desktop\capstone\oldGantryRobot\train2\weights\test1.jpg',conf=0.35)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = YOLO(r'C:\Users\sanka\OneDrive\Desktop\capstone\oldGantryRobot\train2\weights\best.pt')
#       2 res = model.predict(source=r'C:\Users\sanka\OneDrive\Desktop\capstone\oldGantryRobot\train2\weights\test1.jpg',conf=0.35)
#
# NameError: name 'YOLO' is not defined

# %%
# !yolo task=detect mode=predict model=r'C:\Users\sanka\OneDrive\Desktop\capstone\oldGantryRobot\train2\weights\best.pt' conf=0.35 source=r'C:\Users\sanka\OneDrive\Desktop\capstone\oldGantryRobot\train2\weights\test1.jpg' save=True
# Out:
# Ultralytics YOLOv8.0.196  Python-3.8.19 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLOv8n summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#
# [ WARN:0@8.697] global cap_msmf.cpp:471 `anonymous-namespace'::SourceReaderCB::OnReadSample videoio(MSMF): OnReadSample() is called with error status: -1072875772
# [ WARN:0@8.697] global cap_msmf.cpp:483 `anonymous-namespace'::SourceReaderCB::OnReadSample videoio(MSMF): async ReadSample() call is failed with error status: -1072875772
# [ WARN:1@8.697] global cap_msmf.cpp:1759 CvCapture_MSMF::grabFrame videoio(MSMF): can't grab frame. Error: -1072875772
# Traceback (most recent call last):
#   File "C:\Users\sanka\anaconda3\envs\ImageProcessing\Scripts\yolo-script.py", line 9, in <module>
#     sys.exit(entrypoint())
#   File "C:\Users\sanka\anaconda3\envs\ImageProcessing\lib\site-packages\ultralytics\cfg\__init__.py", line 445, in entrypoint
# ...

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(1)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO(r'C:\Users\sanka\OneDrive\Desktop\capstone\oldGantryRobot\train2\weights\best.pt')

# object classes
classNames = ["blank","Test-tubes","Test tubes - v1 2024-07-10 6-43pms","Class3"]


while True:
    success, img = cap.read()
    results = model(img, stream=True)
   
    # coordinates
    for r in results:
        boxes = r.boxes
        #print(boxes)
        for box in boxes:
            print(box)
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print(cls)
            print("Class name -->", classNames[0])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.5363], device='cuda:0')
# data: tensor([[6.1035e+02, 2.8157e+02, 6.2113e+02, 2.9462e+02, 5.3628e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[615.7424, 288.0957,  10.7791,  13.0457]], device='cuda:0')
# xywhn: tensor([[0.9621, 0.6002, 0.0168, 0.0272]], device='cuda:0')
# xyxy: tensor([[610.3529, 281.5729, 621.1320, 294.6185]], device='cuda:0')
# xyxyn: tensor([[0.9537, 0.5866, 0.9705, 0.6138]], device='cuda:0')
# Confidence ---> 0.54
# 0
# Class name --> blank
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([3.], device='cuda:0')
# conf: tensor([0.5017], device='cuda:0')
# data: tensor([[5.0286e+02, 2.5473e+01, 5.1497e+02, 3.5560e+01, 5.0175e-01, 3.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# ...
